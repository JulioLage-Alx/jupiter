# %%
import pandas as pd
import plotly.express as px
from dash import Dash, html, dcc

app = Dash(__name__)

# %%
tabela = pd.read_excel('mec_microdados.xlsx')
display(tabela)
# Out:
# c:\Users\julio\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning:
#
# Cannot parse header or footer so it will be ignored
#        Num_Semestre_Ano  Cod_Instituicao  Cod_Cat_Administrativa  Cod_Curso  \
# 0                200402             1805                       4          6
# 1                200501             1805                       4          2
# 2                200502             1805                       4          2
# 3                200601             1805                       4          2
# 4                200601             1805                       4         96
# ...                 ...              ...                     ...        ...
# 38985            200802             2098                       4          2
# 38986            200802             2098                       4         96
# 38987            200802             2098                       4        266
# ...

# %%
tabela_turno = tabela.groupby('Cod_Turno').sum()
tabela_turno = tabela[['Qtd_Vagas']]
display(tabela_turno)
# Out:
#        Qtd_Vagas
# 0           50.0
# 1           55.0
# 2            NaN
# 3           50.0
# 4           50.0
# ...          ...
# 38985        NaN
# 38986        NaN
# 38987        NaN
# 38988        NaN
# 38989        NaN
#
# [38990 rows x 1 columns]
